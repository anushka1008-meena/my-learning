# %%
print('first','second',sep='-',end='\n\n')
print('''hello python
        It is easy''')

# %%
a = 'Python'
print(a, type(a))
a = 10      
print(a, type(a))

# %%
a = 10
b = int(10.0)    # type casting
c = 10.0
print(id(a))     # for checking memory address we use id
print(id(b))
print(id(c))

# %%
a = input('enter a no: ')
print(a,type(a))

a = int(input('enter a no: '))
print(a,type(a))

# %%
# STRING -> f = between string we can place an variable through f
price = 200
tax = 18
print(f'The price is {price} rupees')
print(f'The price is {price + (price*tax/100} rupees')
print(f'The price is {price:.2f} rupees')    # 2f = 2 zeros at last

# %%
a = 'this is python'
b = 'python'
print(a.isalnum())

# %%
a = '  this is python  '
b = 'python'

result = ''.join([a,b])
print(result)

# print(a.lstrip())   # strip = remove extra spaces

print(a.replace('this is','The'))

# %%
l = 'tipon'
e = '12345'

a = 'this is python'
encoding = a.maketrans(l,e)
print(a.translate(encoding))

# %%
# operators
a = 10
b = 20

print(a == b)
print(a != b)
print(a is b)
print(a is not b)

a = 'this is python'
b = 'this'
if(b in a):
    print('b is substring of a')

# %%
# conditionals

n = 11
if(n>10):
    print('n is greater than 10')
    if(n>12):
        print('n is greater than 12')
    else:
        print('n is less than 12')
else:
    print('n is less than 10')

print('n checked')

# %%
n = 9
print('n is greater than 10') if(n>10) else print('n is smaller than 10')

# %%
for i in range(5):
    print(i)

# %%
# reverse loop
for i  in range(10,0,-1):
    print(i)

# %%
for i in range(1,6,2):   # slicing in for loop
    print(i)

# %%
# break
for i in range(10,0,-1):
    if(i<5):
        break
    print(i)

# %%
# continue
for i in range(10,0,-1):
    if(i%2==0):
        continue
    print(i)

# %%
for i in range(10,0,-1):
    pass
print()

# %%
# user no. input and generate table

a = int(input('enter a no:'))

for i in range(1,11):
    print(f"{a} * {i} = {a*i}")

# %%
for i in range(3,0,-1):
    for j in range(5):
      print(i,j,sep="--")

# %%
# while loop = when values are unknown
c = 'y'
while (c!='x'):
    c = input("Any character and x to exit")

# %%
c = "y"
while(True):
    c = input('Any character and x to exit')
    if(c=='x'):
        break

# %%
# string

str = 'python programming'
print(str[1])
print(str[-1])
print(str[0:5:2])
print(str[-1::-1])    # reverse string last -1 = range

for x in str:         # print 1 by 1
    print(x)
# Out:
# y
# g
# pto
# gnimmargorp nohtyp
# p
# y
# t
# h
# o
# n
#
# p
# r
# o
# g
# r
# a
# m
# m
# i
# n
# g
# 18
# p
# y
# t
# h
# o
# n
#
# p
# r
# o
# g
# r
# a
# m
# m
# i
# n
# g
# 18

# %%
print(len(str))

# find length of string without using len function
c = 0
for x in str:
    print(x)
    c += 1
print(c)
# Out:
# 18
# p
# y
# t
# h
# o
# n
#
# p
# r
# o
# g
# r
# a
# m
# m
# i
# n
# g
# 18

# %%
# ASCII code
print(chr(65))

print(ord('A'))
# Out:
# A
# 65
